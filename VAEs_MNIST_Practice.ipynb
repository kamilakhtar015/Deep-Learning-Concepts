# %% [markdown]
# <a href="https://colab.research.google.com/github/kamilakhtar015/Deep-Learning-Concepts/blob/main/VAEs_MNIST_Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Lets practice Variational Autoencoders (VAEs)")
# Out:
# Lets practice Variational Autoencoders (VAEs)

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras import layers, Model
from tensorflow.keras.datasets import mnist
import matplotlib.pyplot as plt

# %%
# Data, Load, Normalize, Flaten
(x_train, _),(x_test, _) = mnist.load_data()

# Normalize
x_train = x_train.astype("float32") / 255.0
x_test = x_test.astype("float32") / 255.0

# Flatten
original_dim = 28 * 28
x_train = x_train.reshape((-1, original_dim))
x_test = x_test.reshape((-1, original_dim))
# Out:
# ...
# 11490434/11490434 ━━━━━━━━━━━━━━━━━━━━ 0s 0us/step

# %%
# Sampling Layer (reparameterization trick)
class Sampling(layers.Layer):
  def call(self, inputs):
    z_mean, z_log_var = inputs
    epsilon = tf.random.normal(shape=tf.shape(z_mean))
    return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Encoder
latend_dim = 3
